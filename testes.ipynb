# %%
# instalar pySUS
# !pip install pySUS
# Out:
# Collecting pySUS
#   Downloading https://files.pythonhosted.org/packages/b4/97/782a88580528a84a6c1387b67d7044218b7d83c3755e30a6be57f23d7dfa/PySUS-0.3.9.tar.gz (5.2MB)
#      |████████████████████████████████| 5.2MB 4.8MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from pySUS) (0.24.2)
# Collecting dbfread (from pySUS)
#   Downloading https://files.pythonhosted.org/packages/4c/94/51349e43503e30ed7b4ecfe68a8809cdb58f722c0feb79d18b1f1e36fe74/dbfread-2.0.7-py2.py3-none-any.whl
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from pySUS) (1.12.3)
# Collecting geocoder (from pySUS)
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#      |████████████████████████████████| 102kB 17.3MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from pySUS) (2.21.0)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.6/dist-packages (from pySUS) (0.14.1)
# Collecting fastparquet (from pySUS)
#   Downloading https://files.pythonhosted.org/packages/58/49/dccb790fa17ab3fbf84a6b848050083c7a1899e9586000e34e3e4fbf5538/fastparquet-0.3.2.tar.gz (151kB)
#      |████████████████████████████████| 153kB 43.4MB/s
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas->pySUS) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->pySUS) (2018.9)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from pandas->pySUS) (1.16.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.0.0->pySUS) (2.19)
# Collecting ratelim (from geocoder->pySUS)
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from geocoder->pySUS) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from geocoder->pySUS) (1.12.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from geocoder->pySUS) (7.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->pySUS) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->pySUS) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->pySUS) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->pySUS) (2019.6.16)
# Requirement already satisfied: numba>=0.28 in /usr/local/lib/python3.6/dist-packages (from fastparquet->pySUS) (0.40.1)
# Collecting thrift>=0.11.0 (from fastparquet->pySUS)
#   Downloading https://files.pythonhosted.org/packages/c6/b4/510617906f8e0c5660e7d96fbc5585113f83ad547a3989b80297ac72a74c/thrift-0.11.0.tar.gz (52kB)
#      |████████████████████████████████| 61kB 19.2MB/s
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ratelim->geocoder->pySUS) (4.4.0)
# Requirement already satisfied: llvmlite>=0.25.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba>=0.28->fastparquet->pySUS) (0.29.0)
# Building wheels for collected packages: pySUS, fastparquet, thrift
#   Building wheel for pySUS (setup.py) ... done
#   Created wheel for pySUS: filename=PySUS-0.3.9-cp36-cp36m-linux_x86_64.whl size=107970 sha256=6e2ce9946110f6e5ba3b471bd7f2153c0ab4335113cc119313017ea6e85553ab
#   Stored in directory: /root/.cache/pip/wheels/f1/e6/3e/3a64164f17d91918df33db4bd338bcf30e4f61e3ec9325eb54
#   Building wheel for fastparquet (setup.py) ... done
#   Created wheel for fastparquet: filename=fastparquet-0.3.2-cp36-cp36m-linux_x86_64.whl size=253211 sha256=3375ff00ef23207039a8bc3cf6b9b6b58fb358d786f7e292a62546406b6db576
#   Stored in directory: /root/.cache/pip/wheels/b9/36/13/01416a760ddcab0eb8281ec9c9ffcbed945c9b831647c8b904
#   Building wheel for thrift (setup.py) ... done
#   Created wheel for thrift: filename=thrift-0.11.0-cp36-cp36m-linux_x86_64.whl size=326446 sha256=22c150db561f6f63c24b668e61f38b34603e1570ff7aa30548ac621bd36089d1
#   Stored in directory: /root/.cache/pip/wheels/be/36/81/0f93ba89a1cb7887c91937948519840a72c0ffdd57cac0ae8f
# Successfully built pySUS fastparquet thrift
# Installing collected packages: dbfread, ratelim, geocoder, thrift, fastparquet, pySUS
# Successfully installed dbfread-2.0.7 fastparquet-0.3.2 geocoder-1.38.1 pySUS-0.3.9 ratelim-0.1.6 thrift-0.11.0

# %%
# montar para para ler arquivos do drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# pasta_raiz 
root_f = 'drive/My Drive'
project_f = '/Colab Notebooks/analise_exploratoria'
database_root = '/res/database/data'
database_csv = '/csv'
database_dbc = '/dbc'

# %%
from pysus.utilities.readdbc import read_dbc

df = read_dbc(f'{root_f}{project_f}{database_root}{database_dbc}/AC/DNAC2017.dbc', encoding='iso-8859-1')
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-122-23cbcc65caf1> in <module>()
# ----> 1 from pysus.utilities.readdbc import read_dbc
#       2
#       3 df = read_dbc(f'{root_f}{project_f}{database_root}{database_dbc}/AC/DNAC2017.dbc', encoding='iso-8859-1')
#       4 df.dtypes
#
# ModuleNotFoundError: No module named 'pysus'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import plotly.graph_objects as go


colors = [['rgba(38, 24, 74, 0.8)', 'rgba(71, 58, 131, 0.8)',
          'rgba(122, 120, 168, 0.8)'],['rgba(0, 116, 52, 0.8)', 'rgba(0, 176, 80, 0.8)',
          'rgba(0, 234, 106, 0.8)']]

labels = [['Categorias sem ordenação. <br>Ex: sexo, estado civil, <br>fumante/não fumante',
           'Categorias com existência <br>de ordenação. <br>Ex: escolaridade, nível de colesterol, <br>faixa etária',
           'Valores mensuráveis e <br>contáveis (inteiros).<br> Resultado de contagens. <br>Ex: Número de filhos, <br>doses de álcool ingerida', 
           'Valores mensuráveis em <br>escala contínua (reais). <br>Usualmente medidos por instrumento. <br>Ex: idade, altura, pressão arterial'], 
          ['Nominais', 'Ordinais', 'Discretas', 'Contínuas'],
         ['Qualitativas', '', 'Quantitativas']]

x_data = [
          [25, 25, 25, 25],
          [25, 25, 25, 25],
          [50, 0, 50, 0]]

y_data = [' ', '  ', '   ']

fig = go.Figure()

for i in range(0, len(x_data[0])):
    for j, (xd, yd) in enumerate(zip(x_data, y_data)):
        fig.add_trace(go.Bar(
            x=[xd[i]], y=[yd],
            orientation='h',
            hoverinfo ='none',
            marker=dict(
                color=colors[i//2][j],
                line=dict(color='rgb(248, 248, 249)', width=1)
            )
        ))

fig.update_layout(
    xaxis=dict(
        showgrid=False,
        showline=False,
        showticklabels=False,
        zeroline=False,
        domain=[0.0, 1],
        visible=False
    ),
    yaxis=dict(
        showgrid=False,
        showline=False,
        showticklabels=False,
        zeroline=False,
        visible=False
    ),
    barmode='stack',
    paper_bgcolor='rgb(248, 248, 255)',
    plot_bgcolor='rgb(248, 248, 255)',
    margin=dict(l=10, r=10, t=10, b=10),
    showlegend=False,
)

annotations = []

for j, (yd, xd) in enumerate(zip(y_data, x_data)):
    
    annotations.append(dict(xref='x', yref='y',
                            x=xd[0] / 2, y=yd,
                            text=str(labels[j][0]),
                            font=dict(family='Arial', size=16,
                                      color='rgb(248, 248, 255)'),
                            showarrow=False))

    space = xd[0]
    for i in range(1, len(xd)):
      if xd[i] != 0:
            annotations.append(dict(xref='x', yref='y',
                                    x=space + (xd[i]/2), y=yd,
                                    text=str(labels[j][i]),
                                    font=dict(family='Arial', size=16,
                                              color='rgb(248, 248, 255)'),
                                    showarrow=False))

            space += xd[i]

fig.update_layout(annotations=annotations)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4d78c89c-d39b-4e74-8817-6cad5769f36a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4d78c89c-d39b-4e74-8817-6cad5769f36a")) {
#                     Plotly.newPlot(
#                         '4d78c89c-d39b-4e74-8817-6cad5769f36a',
#                         [{"hoverinfo": "none", "marker": {"color": "rgba(38, 24, 74, 0.8)", "line": {"color": "rgb(248, 248, 249)", "width": 1}}, "orientation": "h", "type": "bar", "x": [25], "y": [" "]}, {"hoverinfo": "none", "marker": {"color": "rgba(71, 58, 131, 0.8)", "line": {"color": "rgb(248, 248, 249)", "width": 1}}, "orientation": "h", "type": "bar", "x": [25], "y": ["  "]}, {"hoverinfo": "none", "marker": {"color": "rgba(122, 120, 168, 0.8)", "line": {"color": "rgb(248, 248, 249)", "width": 1}}, "orientation": "h", "type": "bar", "x": [50], "y": ["   "]}, {"hoverinfo": "none", "marker": {"color": "rgba(38, 24, 74, 0.8)", "line": {"color": "rgb(248, 248, 249)", "width": 1}}, "orientation": "h", "type": "bar", "x": [25], "y": [" "]}, {"hoverinfo": "none", "marker": {"color": "rgba(71, 58, 131, 0.8)", "line": {"color": "rgb(248, 248, 249)", "width": 1}}, "orientation": "h", "type": "bar", "x": [25], "y": ["  "]}, {"hoverinfo": "none", "marker": {"color": "rgba(122, 120, 168, 0.8)", "line": {"color": "rgb(248, 248, 249)", "width": 1}}, "orientation": "h", "type": "bar", "x": [0], "y": ["   "]}, {"hoverinfo": "none", "marker": {"color": "rgba(0, 116, 52, 0.8)", "line": {"color": "rgb(248, 248, 249)", "width": 1}}, "orientation": "h", "type": "bar", "x": [25], "y": [" "]}, {"hoverinfo": "none", "marker": {"color": "rgba(0, 176, 80, 0.8)", "line": {"color": "rgb(248, 248, 249)", "width": 1}}, "orientation": "h", "type": "bar", "x": [25], "y": ["  "]}, {"hoverinfo": "none", "marker": {"color": "rgba(0, 234, 106, 0.8)", "line": {"color": "rgb(248, 248, 249)", "width": 1}}, "orientation": "h", "type": "bar", "x": [50], "y": ["   "]}, {"hoverinfo": "none", "marker": {"color": "rgba(0, 116, 52, 0.8)", "line": {"color": "rgb(248, 248, 249)", "width": 1}}, "orientation": "h", "type": "bar", "x": [25], "y": [" "]}, {"hoverinfo": "none", "marker": {"color": "rgba(0, 176, 80, 0.8)", "line": {"color": "rgb(248, 248, 249)", "width": 1}}, "orientation": "h", "type": "bar", "x": [25], "y": ["  "]}, {"hoverinfo": "none", "marker": {"color": "rgba(0, 234, 106, 0.8)", "line": {"color": "rgb(248, 248, 249)", "width": 1}}, "orientation": "h", "type": "bar", "x": [0], "y": ["   "]}],
#                         {"annotations": [{"font": {"color": "rgb(248, 248, 255)", "family": "Arial", "size": 16}, "showarrow": false, "text": "Categorias sem ordena\u00e7\u00e3o. <br>Ex: sexo, estado civil, <br>fumante/n\u00e3o fumante", "x": 12.5, "xref": "x", "y": " ", "yref": "y"}, {"font": {"color": "rgb(248, 248, 255)", "family": "Arial", "size": 16}, "showarrow": false, "text": "Categorias com exist\u00eancia <br>de ordena\u00e7\u00e3o. <br>Ex: escolaridade, n\u00edvel de colesterol, <br>faixa et\u00e1ria", "x": 37.5, "xref": "x", "y": " ", "yref": "y"}, {"font": {"color": "rgb(248, 248, 255)", "family": "Arial", "size": 16}, "showarrow": false, "text": "Valores mensur\u00e1veis e <br>cont\u00e1veis (inteiros).<br> Resultado de contagens. <br>Ex: N\u00famero de filhos, <br>doses de \u00e1lcool ingerida", "x": 62.5, "xref": "x", "y": " ", "yref": "y"}, {"font": {"color": "rgb(248, 248, 255)", "family": "Arial", "size": 16}, "showarrow": false, "text": "Valores mensur\u00e1veis em <br>escala cont\u00ednua (reais). <br>Usualmente medidos por instrumento. <br>Ex: idade, altura, press\u00e3o arterial", "x": 87.5, "xref": "x", "y": " ", "yref": "y"}, {"font": {"color": "rgb(248, 248, 255)", "family": "Arial", "size": 16}, "showarrow": false, "text": "Nominais", "x": 12.5, "xref": "x", "y": "  ", "yref": "y"}, {"font": {"color": "rgb(248, 248, 255)", "family": "Arial", "size": 16}, "showarrow": false, "text": "Ordinais", "x": 37.5, "xref": "x", "y": "  ", "yref": "y"}, {"font": {"color": "rgb(248, 248, 255)", "family": "Arial", "size": 16}, "showarrow": false, "text": "Discretas", "x": 62.5, "xref": "x", "y": "  ", "yref": "y"}, {"font": {"color": "rgb(248, 248, 255)", "family": "Arial", "size": 16}, "showarrow": false, "text": "Cont\u00ednuas", "x": 87.5, "xref": "x", "y": "  ", "yref": "y"}, {"font": {"color": "rgb(248, 248, 255)", "family": "Arial", "size": 16}, "showarrow": false, "text": "Qualitativas", "x": 25.0, "xref": "x", "y": "   ", "yref": "y"}, {"font": {"color": "rgb(248, 248, 255)", "family": "Arial", "size": 16}, "showarrow": false, "text": "Quantitativas", "x": 75.0, "xref": "x", "y": "   ", "yref": "y"}], "barmode": "stack", "margin": {"b": 10, "l": 10, "r": 10, "t": 10}, "paper_bgcolor": "rgb(248, 248, 255)", "plot_bgcolor": "rgb(248, 248, 255)", "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222 ...

# %%
# exportar base do Acre para CSV
df.to_csv(f'{root_f}{project_f}{database_root}{database_csv}/AC/DNAC2017.csv')
